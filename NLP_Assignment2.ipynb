# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk

# Download required NLTK resources (run once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Short text dataset
texts = [
    "Natural language processing is very interesting",
    "Python is widely used for data science",
    "POS tagging helps in understanding sentence structure"
]

# Perform POS tagging
for sentence in texts:
    print("\nSentence:", sentence)

    # Tokenization
    tokens = nltk.word_tokenize(sentence)

    # POS Tagging
    pos_tags = nltk.pos_tag(tokens)

    # Display result
    print("POS Tags:")
    for word, tag in pos_tags:
        print(f"{word} --> {tag}")
# Out:
# Sentence: Natural language processing is very interesting
# POS Tags:
# Natural --> JJ
# language --> NN
# processing --> NN
# is --> VBZ
# very --> RB
# interesting --> JJ
#
# Sentence: Python is widely used for data science
# POS Tags:
# Python --> NNP
# is --> VBZ
# widely --> RB
# used --> VBN
# for --> IN
# data --> NNS
# science --> NN
#
# Sentence: POS tagging helps in understanding sentence structure
# POS Tags:
# POS --> NNP
# tagging --> VBG
# helps --> NNS
# in --> IN
# understanding --> JJ
# sentence --> NN
# structure --> NN
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
