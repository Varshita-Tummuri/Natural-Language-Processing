# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk import ngrams
from nltk.tokenize import word_tokenize

sentence = "The Supreme Court on Monday gave a verdict that changed Priya's life."

tokens = word_tokenize(sentence)

bigrams = list(ngrams(tokens, 2))
trigrams = list(ngrams(tokens, 3))

print("Bigrams: ", bigrams)
print("Trigrams: ", trigrams)
# Out:
# Bigrams:  [('The', 'Supreme'), ('Supreme', 'Court'), ('Court', 'on'), ('on', 'Monday'), ('Monday', 'gave'), ('gave', 'a'), ('a', 'verdict'), ('verdict', 'that'), ('that', 'changed'), ('changed', 'Priya'), ('Priya', "'s"), ("'s", 'life'), ('life', '.')]
# Trigrams:  [('The', 'Supreme', 'Court'), ('Supreme', 'Court', 'on'), ('Court', 'on', 'Monday'), ('on', 'Monday', 'gave'), ('Monday', 'gave', 'a'), ('gave', 'a', 'verdict'), ('a', 'verdict', 'that'), ('verdict', 'that', 'changed'), ('that', 'changed', 'Priya'), ('changed', 'Priya', "'s"), ('Priya', "'s", 'life'), ("'s", 'life', '.')]

# %%
#TOKENIZATION
import string

def tokenize(sentence):
  for p in string.punctuation:
    sentence = sentence.replace(p, " "+p+" ")
  t = sentence.split()
  return t

tokens1 = tokenize(sentence)
print(tokens)
# Out:
# ['The', 'Supreme', 'Court', 'on', 'Monday', 'gave', 'a', 'verdict', 'that', 'changed', 'Priya', "'s", 'life', '.']

# %%
def get_ngrams(n, tokens):
    ngrams = []
    tokens = (n-1)*['<START>'] + tokens
    for i in range(n-1, len(tokens)):
        context = tuple(tokens[i-p-1] for p in reversed(range(n-1)))
        target_word = tokens[i]
        ngrams.append((context, target_word))
    return ngrams

print(get_ngrams(2, tokens))
# Out:
# [(('<START>',), 'The'), (('The',), 'Supreme'), (('Supreme',), 'Court'), (('Court',), 'on'), (('on',), 'Monday'), (('Monday',), 'gave'), (('gave',), 'a'), (('a',), 'verdict'), (('verdict',), 'that'), (('that',), 'changed'), (('changed',), 'Priya'), (('Priya',), "'s"), (("'s",), 'life'), (('life',), '.')]
